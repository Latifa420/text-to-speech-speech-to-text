# %%
pip install ibm_watson
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ibm_cloud_sdk_core
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ibm_watson import TextToSpeechV1

# %%
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
api = IAMAuthenticator ('QZUGUveRSAtu4VHRVjfnGwYOMDziMEzXD4XsP8QxBe7j')

# %%
text_2_speech = TextToSpeechV1(authenticator=api)

# %%
text_2_speech.set_service_url('https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/86e74430-832f-458d-a1e0-14cc8dad300a')

# %%
with open('speech.mp3','wb') as audio_file:
    res = text_2_speech.synthesize('please choose good or bad',accept='audio/mp3').get_result()
    audio_file.write(res.content)
